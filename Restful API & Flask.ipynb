# %% [markdown]
# Q1. What is a RESTful API

# %% [markdown]
# A web service that uses HTTP methods to access and manipulate data in a stateless way.

# %% [markdown]
# Q2. Explain the concept of API specification?

# %% [markdown]
# A document that defines API endpoints, methods, request/response formats.

# %% [markdown]
# Q3. What is Flask, and why is it popular for building APIs?

# %% [markdown]
# A lightweight Python web framework known for its simplicity and flexibility.

# %% [markdown]
# Q4. What is routing in Flask?

# %% [markdown]
# Linking a URL path to a specific function

# %% [markdown]
# Q5. How do you create a simple Flask application?

# %% [markdown]
# Import Flask, define routes with @app.route, and run the app.

# %% [markdown]
# Q6 What are HTTP methods used in RESTful APIs

# %% [markdown]
# GET, POST, PUT, DELETE, PATCH – used for CRUD operations.

# %% [markdown]
# Q7. What is the purpose of the @app.route() decorator in Flask?

# %% [markdown]
# It maps a URL to a Python function

# %% [markdown]
# Q8. What is the difference between GET and POST HTTP methods

# %% [markdown]
# GET retrieves data; POST sends data to the server.

# %% [markdown]
# Q9. How do you handle errors in Flask APIs

# %% [markdown]
# Use @app.errorhandler() to define custom error responses.

# %% [markdown]
# Q10. How do you connect Flask to a SQL database

# %% [markdown]
# Configure SQLALCHEMY_DATABASE_URI and use SQLAlchemy.

# %% [markdown]
# Q11. What is the role of Flask-SQLAlchemy?

# %% [markdown]
# Integrates SQLAlchemy with Flask to simplify database operations.

# %% [markdown]
# Q12. What are Flask blueprints, and how are they useful

# %% [markdown]
# Help organize large apps into modular components.

# %% [markdown]
# Q13. What is the purpose of Flask's request object

# %% [markdown]
# To access incoming request data like JSON, form, method.

# %% [markdown]
# Q14. How do you create a RESTful API endpoint using Flask

# %% [markdown]
# Define a route with @app.route and a function that returns JSON.

# %% [markdown]
# Q15. What is the purpose of Flask's jsonify() function

# %% [markdown]
# Converts Python data to JSON with proper headers.

# %% [markdown]
# Q16. Explain Flask’s url_for() function

# %% [markdown]
# Dynamically generates the URL for a given function name.

# %% [markdown]
# Q17. How does Flask handle static files (CSS, JavaScript, etc.)

# %% [markdown]
# By serving them from the static/ directory.

# %% [markdown]
# Q18. What is an API specification, and how does it help in building a Flask API

# %% [markdown]
# It defines API structure clearly for developers and tools.

# %% [markdown]
# Q19. What are HTTP status codes, and why are they important in a Flask API

# %% [markdown]
# They indicate the result of the request (e.g., 200, 404, 500).

# %% [markdown]
# Q20. How do you handle POST requests in Flask

# %% [markdown]
# Use @app.route(..., methods=['POST']) and request.get_json().

# %% [markdown]
# Q21. How would you secure a Flask API

# %% [markdown]
# Use HTTPS, JWT tokens, input validation, and rate limiting

# %% [markdown]
# Q22. What is the significance of the Flask-RESTful extension

# %% [markdown]
# Simplifies building REST APIs using class-based views.

# %% [markdown]
# Q23. What is the role of Flask’s session object?

# %% [markdown]
# Stores user-specific data (like login state) across requests.

# %% [markdown]
# Practical

# %% [markdown]
# 1. How do you create a basic Flask application?

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello, Flask!'

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# F:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# 2. How do you serve static files like images or CSS in Flask?

# %% [markdown]
# /static
#     /css
#         style.css
#     /images
#         logo.png

# %% [markdown]
# <link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
# <img src="{{ url_for('static', filename='images/logo.png') }}">

# %% [markdown]
# 3. How do you define different routes with different HTTP methods in Flask?

# %%
@app.route('/submit', methods=['GET', 'POST'])
def submit():
    if request.method == 'POST':
        return 'Form Submitted'
    return 'Submit Form'

# %% [markdown]
# 4. How do you render HTML templates in Flask?

# %%
from flask import render_template

@app.route('/')
def index():
    return render_template('index.html')

# %% [markdown]
# 5. How can you generate URLs for routes in Flask using url_for?

# %% [markdown]
# from flask import url_for
#
# @app.route('/about')
# def about():
#     return 'About Page'
#
# @app.route('/')
# def home():
#     return f'Go to <a href="{url_for("about")}">About</a>'

# %% [markdown]
# 6. How do you handle forms in Flask?

# %%
from flask import request

@app.route('/login', methods=['GET', 'POST'])
def login():
    if request.method == 'POST':
        username = request.form['username']
        return f'Logged in as {username}'
    return render_template('login.html')

# %% [markdown]
# 7. How can you validate form data in Flask?

# %%
@app.route('/form', methods=['GET', 'POST'])
def form():
    form = MyForm()
    if form.validate_on_submit():
        return 'Form validated'
    return render_template('form.html', form=form)

# %% [markdown]
# 8. How do you manage sessions in Flask?

# %%
from flask import session

app.secret_key = 'your_secret_key'

@app.route('/set/')
def set_session():
    session['username'] = 'john'
    return 'Session set!'

@app.route('/get/')
def get_session():
    return session.get('username', 'Not set')

# %% [markdown]
# 9. How do you redirect to a different route in Flask?

# %%
from flask import redirect

@app.route('/go-to-home')
def go_home():
    return redirect(url_for('home'))

# %% [markdown]
# 10. How do you handle errors in Flask (e.g., 404)?

# %%
@app.errorhandler(404)
def not_found(e):
    return render_template('404.html'), 404

# %% [markdown]
# 11. How do you structure a Flask app using Blueprints?

# %%
from flask import Blueprint

blog = Blueprint('blog', __name__)

@blog.route('/blog')
def blog_home():
    return 'Blog Home'

# %% [markdown]
# 12. How do you define a custom Jinja filter in Flask?

# %%
@app.template_filter('reverse')
def reverse_filter(s):
    return s[::-1]

# %% [markdown]
# 13. How can you redirect with query parameters in Flask?

# %%
return redirect(url_for('search', q='flask'))
# Out:
#   Cell In[104], line 1
#     return redirect(url_for('search', q='flask'))
#     ^
# SyntaxError: 'return' outside function

# %% [markdown]
# 14. How do you return JSON responses in Flask?

# %%
from flask import jsonify

@app.route('/api/data')
def api_data():
    return jsonify({'name': 'John', 'age': 30})

# %% [markdown]
# 15. How do you capture URL parameters in Flask?

# %%
@app.route('/user/<username>')
def show_user(username):
    return f'User: {username}'
